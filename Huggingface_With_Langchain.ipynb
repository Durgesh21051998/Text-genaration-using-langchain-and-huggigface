# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgesh21051998/Text-genaration-using-langchain-and-huggigface/blob/main/Huggingface_With_Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries install
# !pip install langchain-huggingface
# for api calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 20.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
from google.colab import userdata
Sec_key=userdata.get('HF_TOKEN')
print(Sec_key)
# Out:
# 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

# %% [markdown]
# HuggingFaceEndpoint
#
# How to Access HuggingFace Models with API
#
# There are also two ways to use this class. You can specify the model with the repo_id parameter. Those endpoints use the serverless API, which is particularly beneficial to people using pro accounts or enterprise hub. Still, regular users can already have access to a fair amount of request by connecting with their HF token in the environment where they are executing the code.

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
Sec_key=userdata.get("HUGGINGFACETOKEN")
print(Sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACETOKEN"]=Sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm = HuggingFaceEndpoint(repo_id=repo_id,max_length=200,temperature=0.7,
                          token=Sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm.invoke('what is svm ?')
# Out:
# '\n\nSupport Vector Machines (SVM) is a supervised machine learning algorithm which can be used for both classification and regression challenges. The key objective of SVM is to find a hyperplane (a line in 2D, a plane in 3D, and so on) that separates data of different classes with the maximum margin. The margin is the distance between the hyperplane and the nearest data points of any class, which are called Support Vectors.\n\nThe main advantage of SVM is its ability to handle high-dimensional and nonlinearly separable data by using the concept of kernel functions. Kernel functions map the data from the original space to a higher-dimensional feature space, where the data can be separated by a hyperplane. Commonly used kernel functions are Radial Basis Function (RBF), Linear, Polynomial, and Sigmoid.\n\nSVM has been widely used in various applications such as handwriting recognition, text classification, image classification, medical diagnosis, and bioinformatics. Its robustness agai
# ...

# %%
from langchain import PromptTemplate, LLMChain

# %%
question="Who won the Cricket World Cup 2022?"
template  = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)
print(llm_chain.invoke(question))
# Out:
# {'question': 'Who won the Cricket World Cup 2022?', 'text': ' The Cricket World Cup is an international cricket tournament that takes place every four years. The last Cricket World Cup was held in 2019, won by England. The next Cricket World Cup is scheduled for 2023 in India. So, as of now, no team has won the Cricket World Cup for the year 2022.'}

# %% [markdown]
# HUGGINGPIPELINE

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer,pipeline

# %%
model_id ='openai-community/gpt2'
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe = pipeline('text-generation', model=model , tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke('what is langchain')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'what is langchain and what is it you do when you talk about money and how there shouldn\'t be anything to do in terms of that whatsoever?"\n\nThat isn\'t to say they just want a bigger problem: that this hasn\'t been solved quite yet.\n\nThe problem is that the financial-services industry has not been solving it. The problem is that, since 2000, there has been an exodus of people. And that exodus started in 2007 - we are pretty sure that this influx is happening with or'
